# %%
import numpy as pd

# %%
img = cv2.imread('/home/manikandan/Desktop/image/aaaa.png')

# %%
import cv2
img = cv2.imread('/home/manikandan/Desktop/image/aaaa.jpg')
cv2.imshow('asas',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt





img = cv2.imread('/home/manikandan/Desktop/image/aaaa.jpg',0)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])
plt.show()




# img = cv2.imread('/home/manikandan/Desktop/image/aaaa.jpg',0)
# cv2.imshow('image',img)
# k = cv2.waitKey(0)
# if k == 27:
#     print '---------------------',
#     cv2.destroyAllWindows()
# elif k == ord('s'): 
#     cv2.imwrite('messigray.png',img)
#     cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import pytesseract
from PIL import Image

# Path of working folder on Disk
src_path = "E:/Lab/Python/Project/OCR/"

def get_string(img_path):
    # Read image with opencv
    img = cv2.imread(img_path)

    # Convert to gray
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Apply dilation and erosion to remove some noise
    kernel = np.ones((1, 1), np.uint8)
    img = cv2.dilate(img, kernel, iterations=1)
    img = cv2.erode(img, kernel, iterations=1)

    # Write image after removed noise
    cv2.imwrite(src_path + "removed_noise.png", img)

    #  Apply threshold to get image with only black and white
    #img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)

    # Write the image after apply opencv to do some ...
    cv2.imwrite(src_path + "thres.png", img)

    # Recognize text with tesseract for python
    result = pytesseract.image_to_string(Image.open(src_path + "/home/manikandan/Desktop/image/god.png"))

    # Remove template file
    #os.remove(temp)

    return result


print '--- Start recognize text from image ---'
print get_string(src_path + "2.png")

print "------ Done -------"
# Out:
# --- Start recognize text from image ---
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-9033c22934f6> in <module>()
#      38
#      39 print '--- Start recognize text from image ---'
# ---> 40 print get_string(src_path + "2.png")
#      41
#      42 print "------ Done -------"
#
# <ipython-input-7-9033c22934f6> in get_string(img_path)
#      12
#      13     # Convert to gray
# ---> 14     img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      15
#      16     # Apply dilation and erosion to remove some noise
#
# error: /home/manikandan/opencv/modules/imgproc/src/color.cpp:7564: error: (-215) scn == 3 || scn == 4 in function cvtColor

# %%
from PIL import Image
import pytesseract
import cv2
# import cv

img = cv2.imread('/home/manikandan/Desktop/image/bbbb.jpg')
tex = pytesseract.image_to_string(Image.open("/home/manikandan/Desktop/image/bbbb.jpg"))
# cv2.namedWindow("Input image")
# cv2.imshow('asas',img)
# cv2.waitKey(0)
# cv2.destroyWindow("Test")
# cv2.destroyWindow("Main")
print tex
# Out:
# problems
# manICme | anchpl IC
#
# [13%;]:ij aggressive ‘W
#
# ter‘ISIOf] man i C W‘Scowems MAMIL‘ .
# insomn | a IelmoIIIIIIIIIILMI me | ancho: lc‘Al'ma
#
# gifi'mohlemsm‘e C lic DIEE'MINiiA ““5“”
# dement | 3 mt i" auma dﬁmsentl IIIIIIIIIaIIIu 'IoII
# aggress'vesoI ItaIIII'Ior6b | ems
#
# man i C man IIIIIIIIIII - insecureIIII mm
#
# stsss PROBLEMS a g g r e s s I V e Iggy”
#
# solIIaI-y IiulIhn I’E‘YCNIIT'II
# ﬂags” 3011me ugydis DIEI InOIIII’IdréIIder PIIIIiIiI Imanlc
#
# 'IIAIIMA
#
# "“i'iVithdra al$()|.i 'I'I\li\'
#
# dementia
# 'I‘ISUMIIiIi iIIsoMIIiII nun MELIIIIIIIIIIIII: IIIII'I'cun: o IIIiCII in
# tension igIIIIaiiure I “'0 II
# III: l’lili IIIIIIII mg efme a n C
#
# Ire I: m Ii‘ii‘iii‘ii III I'IIIIIIIIIIIII l.
#
# iI\ 5‘) I“ Ni ‘\ W 'Gllill PSKI‘IHH' Iii IlElIiSIim WimllMW/ll
#
# IIIIIIII III:IIIIEIIIIIIIIunusmu II ISiIIi Eli
# gr riefII'". IIIII III: Ml: N I IHii’I‘IIIiIIII;
#
# niSi)|il)l.-ll IIIsIIIIIIIII I E N"i 0“ |”““ Stress IEIIWI'IIIMIIII
# ...

# %%
import cv2
import numpy as np
img = cv2.imread('/home/manikandan/Desktop/image/god.png',0)
ret,thresh = cv2.threshold(img,127,255,0)
im2,contours,hierarchy = cv2.findContours(thresh, 1, 2)
cnt = contours[0]
M = cv2.moments(cnt)
print( M )
# Out:
# {'mu02': 0.3333333333139308, 'mu03': 1.4901161193847656e-08, 'm11': 74932.0, 'nu02': 0.0833333333284827, 'm12': 21430595.666666668, 'mu21': 2.0081643015146255e-09, 'mu20': 0.3333333333284827, 'nu20': 0.08333333333212067, 'm30': 4496313.0, 'nu21': 3.549966488344346e-10, 'mu11': 0.0, 'mu12': 3.7834979593753815e-09, 'nu11': 0.0, 'nu12': 6.688342659199493e-10, 'm02': 163592.3333333333, 'm03': 46787598.0, 'm00': 2.0, 'm01': 572.0, 'mu30': 1.862645149230957e-09, 'nu30': 3.2927225399135965e-10, 'nu03': 2.634178031930877e-09, 'm10': 262.0, 'm20': 34322.33333333333, 'm21': 9816187.333333334}

# %%
import numpy
import cv2
img = cv2.imread('/home/manikandan/Desktop/image/god.png',cv2.IMREAD_COLOR)
cv2.line(img,(0,0),(1,1),(255,0,0),15)
cv2.rectangle(img,(1,2),(30,48),(0,255,0),5)
cv2.imshow('asas',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
import math

class ShapeRecong():
          def __init__(self,img):
               self.img = img
          def preprocessing(self):
               lower = np.array([0,0,0],dtype=np.uint8)
               upper = np.array([12,12,12],dtype=np.uint8)
               mask = cv2.inRange(self.img,lower,upper)
               cv2.imshow("mask",mask)
               (flags,contours,h) =    cv2.findContours(mask,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
               return contours


img = cv2.imread("/home/manikandan/Desktop/image/god.png")
shape =ShapeRecong(img)
contours = shape.preprocessing()

cv2.imshow('asasa',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
